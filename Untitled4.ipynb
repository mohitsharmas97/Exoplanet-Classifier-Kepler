# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitsharmas97/Exoplanet-Classifier-Kepler/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nasa/kepler-exoplanet-search-results")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/kepler-exoplanet-search-results

# %%
cd /root/.cache/kagglehub/datasets/nasa/kepler-exoplanet-search-results/versions/2
# Out:
# /root/.cache/kagglehub/datasets/nasa/kepler-exoplanet-search-results/versions/2

# %%
ls
# Out:
# cumulative.csv

# %%
dataset=pd.read_csv("cumulative.csv")
dataset.head(3)
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# ...

# %%
dataset.shape
# Out:
# (9564, 50)

# %%
dataset_cleaned.isnull().sum()
# Out:
# rowid                   0
# kepid                   0
# kepoi_name              0
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_plnt_num      346
# koi_tce_delivname     346
# ...

# %%
selected_columns = [
    'koi_period',
    'koi_prad',
    'koi_teq',
    'koi_insol',
    'koi_steff',
    'koi_srad',
    'koi_slogg',
    'koi_kepmag',
    'koi_score',
    'koi_disposition',



]

dataset_selected = dataset[selected_columns]
display(dataset_selected.head())
# Out:
#    koi_period  koi_prad  koi_teq  koi_insol  koi_steff  koi_srad  koi_slogg  \
# 0    9.488036      2.26    793.0      93.59     5455.0     0.927      4.467
# 1   54.418383      2.83    443.0       9.11     5455.0     0.927      4.467
# 2   19.899140     14.60    638.0      39.30     5853.0     0.868      4.544
# 3    1.736952     33.46   1395.0     891.96     5805.0     0.791      4.564
# 4    2.525592      2.75   1406.0     926.16     6031.0     1.046      4.438
#
#    koi_kepmag  koi_score koi_disposition
# 0      15.347      1.000       CONFIRMED
# 1      15.347      0.969       CONFIRMED
# 2      15.436      0.000  FALSE POSITIVE
# 3      15.597      0.000  FALSE POSITIVE
# 4      15.509      1.000       CONFIRMED

# %%
dataset_selected.isnull().sum()
# Out:
# koi_period            0
# koi_prad            363
# koi_teq             363
# koi_insol           321
# koi_steff           363
# koi_srad            363
# koi_slogg           363
# koi_kepmag            1
# koi_score          1510
# koi_disposition       0
# dtype: int64

# %%
columns_to_fill = [
    'koi_prad',
    'koi_teq',
    'koi_insol',
    'koi_steff',
    'koi_srad',
    'koi_slogg',
    'koi_kepmag',
    'koi_score'

]

for column in columns_to_fill:
    dataset_selected[column] = dataset_selected[column].fillna(dataset_selected[column].mean())

display(dataset_selected.isnull().sum())
# Out:
# /tmp/ipython-input-295-382246886.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_selected[column] = dataset_selected[column].fillna(dataset_selected[column].mean())
# koi_period         0
# koi_prad           0
# koi_teq            0
# koi_insol          0
# koi_steff          0
# koi_srad           0
# koi_slogg          0
# koi_kepmag         0
# koi_score          0
# koi_disposition    0
# dtype: int64

# %%
dataset_selected.head(3)
# Out:
#    koi_period  koi_prad  koi_teq  koi_insol  koi_steff  koi_srad  koi_slogg  \
# 0    9.488036      2.26    793.0      93.59     5455.0     0.927      4.467
# 1   54.418383      2.83    443.0       9.11     5455.0     0.927      4.467
# 2   19.899140     14.60    638.0      39.30     5853.0     0.868      4.544
#
#    koi_kepmag  koi_score koi_disposition
# 0      15.347      1.000       CONFIRMED
# 1      15.347      0.969       CONFIRMED
# 2      15.436      0.000  FALSE POSITIVE

# %%
dataset_selected.shape
# Out:
# (9564, 10)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming dataset_selected has no nulls at this point
# and 'koi_disposition' is still the original text column

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Create the single-column numerical target
y = label_encoder.fit_transform(dataset_selected['koi_disposition'])

# Your features (X) will be all other columns except the original 'koi_disposition'
# Use .drop() on the original dataset_selected
x = dataset_selected.drop(columns=['koi_disposition'])

print("Shape of X:", x.shape)
print("Shape of y:", y.shape) # This should now be a 1D array, e.g., (X_samples,)
# Out:
# Shape of X: (9564, 9)
# Shape of y: (9564,)

# %%
dataset_selected.shape
# Out:
# (9564, 10)

# %%
dataset_selected.head(3)
# Out:
#    koi_period  koi_prad  koi_teq  koi_insol  koi_steff  koi_srad  koi_slogg  \
# 0    9.488036      2.26    793.0      93.59     5455.0     0.927      4.467
# 1   54.418383      2.83    443.0       9.11     5455.0     0.927      4.467
# 2   19.899140     14.60    638.0      39.30     5853.0     0.868      4.544
#
#    koi_kepmag  koi_score koi_disposition
# 0      15.347      1.000       CONFIRMED
# 1      15.347      0.969       CONFIRMED
# 2      15.436      0.000  FALSE POSITIVE

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
# It's crucial to fit only on training data to prevent data leakage from the test set
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

print("\nFeatures scaled successfully.")
print("Example of scaled training features (first 3 rows, first 3 columns):\n", x_train_scaled[:3, :3])
# Out:
# Features scaled successfully.
# Example of scaled training features (first 3 rows, first 3 columns):
#  [[-5.32757844e-02 -1.36682387e-02  1.80365551e+00]
#  [-5.30764282e-02 -7.43341201e-04  9.12519630e-01]
#  [-5.05974205e-02 -3.48494689e-02 -2.98997998e-01]]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)

# IMPORTANT: Fit the model using the SCALED training data
model.fit(x_train_scaled,y_train)

# IMPORTANT: Score the model using the SCALED testing data
model.score(x_test_scaled,y_test),model.score(x_train_scaled,y_train)
# Out:
# (0.7783585990590696, 0.7800287544111881)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize the Random Forest Classifier
# You can adjust parameters like n_estimators, max_depth, random_state, etc.
model_rf = RandomForestClassifier(n_estimators=16, random_state=42)

# %%
# Fit the model to the scaled training data
model_rf.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_estimators=16, random_state=42)

# %%
model_rf.score(x_test_scaled,y_test),model_rf.score(x_train_scaled,y_train)
# Out:
# (0.8076319916361735, 0.9973859626192655)

# %%
from sklearn.svm import SVC

# %%
# Initialize the SVM Classifier
# You can adjust parameters like C, kernel, gamma, etc.
model_svm = SVC(random_state=42)

# %%
# Fit the model to the scaled training data
model_svm.fit(x_train_scaled, y_train)
# Out:
# SVC(random_state=42)

# %%
model_svm.score(x_test_scaled,y_test),model.score(x_train_scaled,y_train)
# Out:
# (0.785154208050183, 0.7800287544111881)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Initialize the KNN Classifier
# You can adjust the number of neighbors (n_neighbors)
model_knn = KNeighborsClassifier(n_neighbors=20)

# %%
# Fit the model to the scaled training data
model_knn.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
model_knn.score(x_test_scaled,y_test),model.score(x_train_scaled,y_train)
# Out:
# (0.7746994249869316, 0.7800287544111881)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Get predictions for each model
y_pred_lr = model.predict(x_test_scaled)
y_pred_rf = model_rf.predict(x_test_scaled)
y_pred_svm = model_svm.predict(x_test_scaled)
y_pred_knn = model_knn.predict(x_test_scaled)

# Create a mapping for the original labels for better visualization
# Assuming the order from LabelEncoder is 0 for CANDIDATE, 1 for CONFIRMED, 2 for FALSE POSITIVE
label_mapping = {0: 'CANDIDATE', 1: 'CONFIRMED', 2: 'FALSE POSITIVE'}
y_test_labels = np.array([label_mapping[i] for i in y_test])
y_pred_lr_labels = np.array([label_mapping[i] for i in y_pred_lr])
y_pred_rf_labels = np.array([label_mapping[i] for i in y_pred_rf])
y_pred_svm_labels = np.array([label_mapping[i] for i in y_pred_svm])
y_pred_knn_labels = np.array([label_mapping[i] for i in y_pred_knn])


# Function to create scatter plot
def plot_actual_vs_predicted(actual_labels, predicted_labels, model_name):
    plt.figure(figsize=(8, 6))
    # Using jitter to better visualize overlapping points
    sns.stripplot(x=actual_labels, y=predicted_labels, jitter=0.2, alpha=0.5)
    plt.title(f'Actual vs. Predicted Disposition ({model_name})')
    plt.xlabel('Actual Disposition')
    plt.ylabel('Predicted Disposition')
    plt.grid(True)
    plt.show()

# Plot for each model
plot_actual_vs_predicted(y_test_labels, y_pred_lr_labels, 'Logistic Regression')
plot_actual_vs_predicted(y_test_labels, y_pred_rf_labels, 'Random Forest')
plot_actual_vs_predicted(y_test_labels, y_pred_svm_labels, 'SVM')
plot_actual_vs_predicted(y_test_labels, y_pred_knn_labels, 'KNN')

# %%
from sklearn.metrics import confusion_matrix


# Function to plot confusion matrix
def plot_confusion_matrix(actual, predicted, model_name, labels):
    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(4,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.title(f'Confusion Matrix ({model_name})')
    plt.xlabel('Predicted Disposition')
    plt.ylabel('Actual Disposition')
    plt.show()

# Plot confusion matrix for each model
plot_confusion_matrix(y_test_labels, y_pred_lr_labels, 'Logistic Regression', label_mapping.values())
plot_confusion_matrix(y_test_labels, y_pred_rf_labels, 'Random Forest', label_mapping.values())
plot_confusion_matrix(y_test_labels, y_pred_svm_labels, 'SVM', label_mapping.values())
plot_confusion_matrix(y_test_labels, y_pred_knn_labels, 'KNN', label_mapping.values())

# %%
import joblib

# Save the Logistic Regression model to a file in a writable directory
joblib.dump(model, '/content/logistic_regression_model.joblib')

print("Logistic Regression model saved successfully to '/content/logistic_regression_model.joblib'")
# Out:
# Logistic Regression model saved successfully to '/content/logistic_regression_model.joblib'
